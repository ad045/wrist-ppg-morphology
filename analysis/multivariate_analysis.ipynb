# %%
# Setup: Only run once

import os

# move up from notebooks → project root
os.chdir(os.path.join(os.getcwd(), os.pardir))
print("Working dir is now:", os.getcwd())

from initialize import PREPROCESSED_AURORA_DATA_PATH

# %load_ext autoreload
# %autoreload 2
# Out:
# Working dir is now: /Users/adrian/Documents/01_projects/02_clean_ppg

# %%
DICT_PATH = PREPROCESSED_AURORA_DATA_PATH + "/data_dict_osc_auc_with_derivatives.pt"

# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/multivariate_analysis.py --data_pt $DICT_PATH
# Out:
# [INFO] Loading /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_osc_auc_with_derivatives.pt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/01_projects/02_clean_ppg/analysis/multivariate_analysis.py:237
#     233         run_analysis(args.data_pt, wave_level=False, out_folder=out)
#     236 if __name__ == "__main__":
# --> 237     main()
#
# File ~/Documents/01_projects/02_clean_ppg/analysis/multivariate_analysis.py:230, in main(argv)
#     227 out.mkdir(exist_ok=True)
#     229 if not args.skip_wave_level:
# --> 230     run_analysis(args.data_pt, wave_level=True, out_folder=out)
#     232 if not args.skip_ensemble_level:
#     233     run_analysis(args.data_pt, wave_level=False, out_folder=out)
#
# File ~/Documents/01_projects/02_clean_ppg/analysis/multivariate_analysis.py:161, in run_analysis(pt_file, wave_level, out_folder)
#     157 _correlation_heatmap(df, candidate_x + [outcome],
#     158                      out_folder / f"corr_{level}.png")
#     160 # --------------------------- univariate --------------------------------
# --> 161 uni = _univariate_ols(df, outcome, candidate_x)
#     162 uni.to_csv(out_folder / f"univariate_{level}.csv", index=False)
#     163 print(f"[INFO] Univariate stats saved → univariate_{level}.csv")
#
# File ~/Documents/01_projects/02_clean_ppg/analysis/multivariate_analysis.py:95, in _univariate_ols(df, y, xcols)
#      93 records = []
#      94 for x in xcols:
# ---> 95     model = sm.OLS(df[y], sm.add_constant(df[[x]])).fit()
#      96     beta  = model.params[x]
#      97     se    = model.bse[x]
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
#     922                           hasconst=hasconst, **kwargs)
#     923 if "weights" in self._init_keys:
#     924     self._init_keys.remove("weights")
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:746, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     744 else:
#     745     weights = weights.squeeze()
# --> 746 super().__init__(endog, exog, missing=missing,
#     747                           weights=weights, hasconst=hasconst, **kwargs)
#     748 nobs = self.exog.shape[0]
#     749 weights = self.weights
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:200, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     199 def __init__(self, endog, exog, **kwargs):
# --> 200     super().__init__(endog, exog, **kwargs)
#     201     self.pinv_wexog: Float64Array | None = None
#     202     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/base/model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/base/model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/base/model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/base/data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     exog = np.asarray(exog)
#     674 klass = handle_data_class_factory(endog, exog)
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676              **kwargs)
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/base/data.py:84, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      82     self.orig_endog = endog
#      83     self.orig_exog = exog
# ---> 84     self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      86 self.const_idx = None
#      87 self.k_constant = 0
#
# File /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/statsmodels/base/data.py:509, in PandasData._convert_endog_exog(self, endog, exog)
#     507 exog = exog if exog is None else np.asarray(exog)
#     508 if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 509     raise ValueError("Pandas data cast to numpy dtype of object. "
#     510                      "Check input data with np.asarray(data).")
#     511 return super()._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
# ⇒ creates ./reports/ with .csv, .tex and .png assets
data_path = os.path.join(
    PREPROCESSED_MAUS_DATA_PATH, "data_dict_osc_auc_with_derivatives.pt"
)

# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/multivariate_analysis.py --data_pt /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_osc_auc_with_derivatives.pt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # ⇒ creates ./reports/ with .csv, .tex and .png assets
#       2 data_path = os.path.join(
# ----> 3     PREPROCESSED_MAUS_DATA_PATH, "data_dict_osc_auc_with_derivatives.pt"
#       4 )
#       6 get_ipython().run_line_magic('run', '/Users/adrian/Documents/01_projects/02_clean_ppg/analysis/multivariate_analysis.py --data_pt /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_osc_auc_with_derivatives.pt')
#
# NameError: name 'PREPROCESSED_MAUS_DATA_PATH' is not defined
