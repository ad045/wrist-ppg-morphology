# %% [markdown]
# # Setup: Only run once

# %%
import os

# move up from notebooks -> project root
os.chdir(os.path.join(os.getcwd(),os.pardir))
print("Working dir is now:", os.getcwd())

from initialize import RAW_MAUS_DATA_PATH, PREPROCESSED_MAUS_DATA_PATH
# Out:
# Working dir is now: /Users/adrian/Documents/01_projects/02_clean_ppg

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Extract durations of waves with different algorithms

# %%
# Vanilla pyPPG
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/compare_durations/get_wave_durations_for_vanilla_pyppg.py         --device finger --raw_path $RAW_MAUS_DATA_PATH --out_dir $PREPROCESSED_MAUS_DATA_PATH
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/compare_durations/get_wave_durations_for_vanilla_pyppg.py         --device wrist  --raw_path $RAW_MAUS_DATA_PATH --out_dir $PREPROCESSED_MAUS_DATA_PATH
# Out:
# [INFO] Processing device = finger
# [INFO] Raw path         = /Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data
# [INFO] 002 → inf_resting.csv
# /Users/adrian/Documents/01_projects/02_clean_ppg/pyPPG/fiducials.py:65: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...

# %%
# NeuroKit2
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/compare_durations/get_wave_durations_for_vanilla_neurokit2.py         --device finger --raw_path $RAW_MAUS_DATA_PATH --out_dir $PREPROCESSED_MAUS_DATA_PATH
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/compare_durations/get_wave_durations_for_vanilla_neurokit2.py         --device wrist  --raw_path $RAW_MAUS_DATA_PATH --out_dir $PREPROCESSED_MAUS_DATA_PATH
# Out:
# [INFO] Processing files for device: finger
# [INFO] Raw data path: /Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data
# [INFO] Processing subject: 002  →  /Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data/002/inf_resting.csv
# [INFO] Processing subject: 004  →  /Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data/004/inf_resting.csv
# [INFO] Processing subject: 005  →  /Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data/005/inf_resting.csv
# [INFO] Processing subject: 006  →  /Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data/006/inf_resting.csv
# [INFO] Processing subject: 008  →  /Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data/008/inf_resting.csv
# [INFO] Processing subject: 010  →  /Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data/010/inf_resting.csv
# ...

# %%
# Custom pipeline
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/compare_durations/get_wave_durations_for_custom_pipeline.py
# Out:
# 1770
# 7755

# %% [markdown]
# # Compare & Plot

# %%
# Compare
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/compare_durations/compare_durations.py
# Out:
# Loaded custom_finger with 1770 samples.
# Loaded custom_wrist with 7755 samples.
# Loaded pyppg_finger with 7826 samples.
# Loaded pyppg_wrist with 7409 samples.
# Loaded neurokit_finger with 7909 samples.
# Loaded neurokit_wrist with 7742 samples.
# Labels: ['custom_finger', 'custom_wrist', 'pyppg_finger', 'pyppg_wrist', 'neurokit_finger', 'neurokit_wrist']
