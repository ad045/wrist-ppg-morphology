# %%
import os

# move up from notebooks → project root
os.chdir(os.path.join(os.getcwd(), os.pardir))
print("Working dir is now:", os.getcwd())

from initialize import PREPROCESSED_AURORA_DATA_PATH

# %load_ext autoreload
# %autoreload 2
# Out:
# Working dir is now: <will give you the path of the project on your computer (i.e.: should end with '/clean_ppg_project')>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Perform multivariate regression

# %%
DICT_PATH = PREPROCESSED_AURORA_DATA_PATH + "/data_dict_osc_auc_with_derivatives.pt"

# %run <your_path>/analysis/aurora_analysis.py --dict_path $DICT_PATH --classify --analyse # --verbose
