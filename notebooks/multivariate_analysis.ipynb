# %% [markdown]
# # Setup

# %%
# Setup: Only run once

import os

# move up from notebooks → project root
os.chdir(os.path.join(os.getcwd(), os.pardir))
print("Working dir is now:", os.getcwd())

from initialize import PREPROCESSED_AURORA_DATA_PATH

# %load_ext autoreload
# %autoreload 2
# Out:
# Working dir is now: /Users/adrian/Documents/01_projects/02_clean_ppg

# %% [markdown]
# # Perform multivariate regression

# %%
DICT_PATH = PREPROCESSED_AURORA_DATA_PATH + "/data_dict_osc_auc_with_derivatives.pt"

# %run /Users/adrian/Documents/01_projects/02_clean_ppg/analysis/aurora_analysis.py --dict_path $DICT_PATH --classify --analyse
# --verbose

# Episches Zeug: Hier die notebook felder debuggen...
# Out:
# INFO: Loading → /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_osc_auc_with_derivatives.pt
# INFO: Classifying pulse waves …
# INFO: Labelling pulse waves …
# INFO: Classes written to /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_osc_auc_with_derivatives_with_classes.pt
# INFO: Running analysis on 686 entries
# INFO: DataFrame created with 686 rows
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# INFO: Multivariate regression finished(R² = 0.542) for variable 'rise_time_ms'
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# INFO: Multivariate regression finished(R² = 0.190) for variable 'area_under_the_curve_sign'
# INFO: Figures → /Users/adrian/Documents/01_projects/02_clean_ppg/output/regression/figures | Tables → /Users/adrian/Documents/01_projects/02_clean_ppg/output/regression/tables
# There were True rows with NaNs in X or y, which were removed.
# There were True rows with NaNs in X or y, which were removed.
