# %% [markdown]
# # Setup: Only run once

# %%
import os

# move up from notebooks → project root
os.chdir(os.path.join(os.getcwd(), os.pardir))
print("Working dir is now:", os.getcwd())

from initialize import RAW_MAUS_DATA_PATH, PREPROCESSED_MAUS_DATA_PATH
# Out:
# Working dir is now: /Users/adrian/Documents/01_projects/02_clean_ppg

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Preprocessing

# %%
# Generally: 
# python -m preprocessing \
#        --dataset_type maus_finger \
#        --raw_path   "/Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/raw/Raw_data" \                 # can be left empty to use the default path
#        --output_path "/Users/adrian/Documents/01_projects/00_ppg_project/data/MAUS/preprocessed" \                # can be left empty to use the default path
#        --post_filter

# %%
# MAUS: either maus_wrist, maus_finger, maus 
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/preprocessing/preprocessing.py --dataset_type maus_finger --post_filter
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/preprocessing/preprocessing.py --dataset_type maus_wrist --post_filter 

# AURORA: either aurora_osc, aurora_auc, aurora
# %run /Users/adrian/Documents/01_projects/02_clean_ppg/preprocessing/preprocessing.py --dataset_type aurora --post_filter

# 1 minute 43 seconds approx
# Out:
# Raw stage is going to be performed (no --skip_raw)
# Running datasets: ['maus_finger']
#
# === Processing maus_finger dataset ===
# Processing maus_finger data.
# Step 1: Load metadata and get waveform folder based on dataset type
# [INFO] MAUS resting loader – 21 files found (finger)
# Step 2: Create dictionary for each participant
# Step 3: Process each subject's raw optical signal with pyPPG (initial derivatives)
# Step 4: Split into individual waves, compute ensemble wave, average HR, and compute derivatives
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/miniconda3/envs/ppg_project/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Step 5: Save final dictionary
# Final dictionary saved as /Users/adrian/Documents/01_projects/02_clean_ppg/data/MAUS/preprocessed/data_dict_maus_finger.pt
# [INFO] Loading → /Users/adrian/Documents/01_projects/02_clean_ppg/data/MAUS/preprocessed/data_dict_maus_finger.pt
# [INFO] Kept 1756/1770 waves (99.2 %)
# [INFO] Saved cleaned dictionary → /Users/adrian/Documents/01_projects/02_clean_ppg/data/MAUS/preprocessed/data_dict_maus_finger_filtered.pt
# Raw stage is going to be performed (no --skip_raw)
# Running datasets: ['maus_wrist']
#
# === Processing maus_wrist dataset ===
# Processing maus_wrist data.
# Step 1: Load metadata and get waveform folder based on dataset type
# [INFO] MAUS resting loader – 21 files found (wrist)
# Step 2: Create dictionary for each participant
# Step 3: Process each subject's raw optical signal with pyPPG (initial derivatives)
# Step 4: Split into individual waves, compute ensemble wave, average HR, and compute derivatives
# Step 5: Save final dictionary
# Final dictionary saved as /Users/adrian/Documents/01_projects/02_clean_ppg/data/MAUS/preprocessed/data_dict_maus_wrist.pt
# [INFO] Loading → /Users/adrian/Documents/01_projects/02_clean_ppg/data/MAUS/preprocessed/data_dict_maus_wrist.pt
# [INFO] Kept 7755/7755 waves (100.0 %)
# [INFO] Saved cleaned dictionary → /Users/adrian/Documents/01_projects/02_clean_ppg/data/MAUS/preprocessed/data_dict_maus_wrist_filtered.pt
# Raw stage is going to be performed (no --skip_raw)
# Running datasets: ['oscillometric', 'auscultatory']
#
# === Processing oscillometric dataset ===
# Processing oscillometric data.
# Step 1: Load metadata and get waveform folder based on dataset type
# Step 2: Create dictionary for each participant
# Step 3: Process each subject's raw optical signal with pyPPG (initial derivatives)
# Step 4: Split into individual waves, compute ensemble wave, average HR, and compute derivatives
# Step 5: Save final dictionary
# Final dictionary saved as /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_oscillometric.pt
#
# === Processing auscultatory dataset ===
# Processing auscultatory data.
# Step 1: Load metadata and get waveform folder based on dataset type
# Step 2: Create dictionary for each participant
# Step 3: Process each subject's raw optical signal with pyPPG (initial derivatives)
# Skipping subject a017 due to insufficient signal length.
# Skipping subject a017 due to insufficient signal length.
# Skipping subject a025 due to insufficient signal length.
# Skipping subject a025 due to insufficient signal length.
# Skipping subject a486 due to insufficient signal length.
# Skipping subject a486 due to insufficient signal length.
# Skipping subject a535 due to insufficient signal length.
# Skipping subject a535 due to insufficient signal length.
# Skipping subject a645 due to insufficient signal length.
# Skipping subject a645 due to insufficient signal length.
# Skipping subject a667 due to insufficient signal length.
# Skipping subject a667 due to insufficient signal length.
# Step 4: Split into individual waves, compute ensemble wave, average HR, and compute derivatives
# Step 5: Save final dictionary
# Final dictionary saved as /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_auscultatory.pt
# Merging datasets and adding regressors
# Saved merged data_dict with derivatives to: /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_osc_auc_with_derivatives.pt
# [INFO] Loading → /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_oscillometric.pt
# [INFO] Kept 9380/9383 waves (100.0 %)
# [INFO] Saved cleaned dictionary → /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_oscillometric_filtered.pt
# [INFO] Loading → /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_auscultatory.pt
# [INFO] Kept 8490/8490 waves (100.0 %)
# [INFO] Saved cleaned dictionary → /Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_auscultatory_filtered.pt

# %%
import torch 

dd = torch.load("/Users/adrian/Documents/01_projects/02_clean_ppg/data/AURORA/preprocessed/data_dict_osc_auc_with_derivatives.pt", weights_only=False)
print("Number of subjects in AURORA data_dict:", len(dd))
dd.keys()
# Out:
# Number of subjects in AURORA data_dict: 686
# dict_keys(['a000', 'a001', 'a002', 'a005', 'a007', 'a009', 'a011', 'a013', 'a014', 'a018', 'a019', 'a020', 'a021', 'a022', 'a027', 'a029', 'a032', 'a034', 'a035', 'a040', 'a041', 'a043', 'a044', 'a045', 'a047', 'a048', 'a049', 'a050', 'a051', 'a052', 'a053', 'a057', 'a058', 'a060', 'a064', 'a065', 'a067', 'a069', 'a070', 'a071', 'a073', 'a074', 'a075', 'a076', 'a078', 'a079', 'a080', 'a081', 'a084', 'a085', 